# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab

# %% [markdown]
# # Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.

# %% [markdown]
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Practice
#
# ## Objectives
# You will be able to:
# * Understand and explain what Pandas Series and DataFrames are and how they differ from dictionaries and lists
# * Create Series & DataFrames from dictionaries and lists
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes

# %% [markdown]
# # Rename all the columns to lower case

# %%
for column in df.columns:
    df = df.rename(columns={column:column.lower()})

# %%
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# # Change the Index to be the Line Names

# %%
df = df.set_index('linename')
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# # Painstakingly change the index back

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    index linename   c/a  unit       scp station division        date  \
# 0      0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 1      1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 2      2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 3      3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 4      4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
#
#        time     desc  entries  \
# 0  00:00:00  REGULAR  6736067
# 1  04:00:00  REGULAR  6736087
# 2  08:00:00  REGULAR  6736105
# 3  12:00:00  REGULAR  6736180
# 4  16:00:00  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order.

# %%
df['num_lines'] = df.linename.map(lambda x: len(x))

# %%
df.head()
# Out:
#    index linename   c/a  unit       scp station division        date  \
# 0      0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 1      1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 2      2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 3      3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
# 4      4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018
#
#        time     desc  entries    exits  num_lines
# 0  00:00:00  REGULAR  6736067  2283184          7
# 1  04:00:00  REGULAR  6736087  2283188          7
# 2  08:00:00  REGULAR  6736105  2283229          7
# 3  12:00:00  REGULAR  6736180  2283314          7
# 4  16:00:00  REGULAR  6736349  2283384          7

# %% [markdown]
# ## Write a function to clean a column name.

# %%
def clean(col_name):
    return col_name.strip()

# %%
#This is a list comprehension. It applies your clean function to every item in the list.
#We then reassign that to df.columns
#You shouldn't have to change anything here.
#Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
#Checking the output, we can see the results.
df.columns
# Out:
# Index(['index', 'linename', 'c/a', 'unit', 'scp', 'station', 'division',
#        'date', 'time', 'desc', 'entries', 'exits', 'num_lines'],
#       dtype='object')

# %% [markdown]
# ## Compare subway traffic by day of the week. Display this as a graph.

# %%
df['date'] = pd.to_datetime(df['date'])
df['day_of_week'] = df['date'].dt.day_name()b

# %%
df.head()
# Out:
#     c/a  unit       scp station linename division       date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2018-08-25  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits                                                                 \
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384
#
#    num_lines day_of_week
# 0          7    Saturday
# ...

# %%
days = df.groupby(df.day_of_week).sum()
days.plot(kind='barh')

# %%
days
# Out:
#                    entries  \
# day_of_week
# Friday       1110224700078
# Monday       1114237052454
# Saturday     1115661545514
# Sunday       1192306179082
# Thursday     1122723988662
# Tuesday      1143313287046
# Wednesday    1123655222441
#
#              exits                                                                 \
# day_of_week
# Friday                                            906799065337
# Monday                                            911938153513
# Saturday                                          909142081474
# Sunday                                            959223750461
# Thursday                                          920691927110
# Tuesday                                           942230721477
# Wednesday                                         920630864687
#
#              num_lines
# day_of_week
# Friday           75573
# Monday           76110
# Saturday         74725
# Sunday           75306
# Thursday         76607
# Tuesday          77303
# ...

# %% [markdown]
# ## Is there more subway traffic on a weekend or a weekday?    Be specific in comparing magnitudes.

# %%
days.reset_index()
# Out:
#   day_of_week        entries         exits  num_lines
# 0      Friday  1110224700078  906799065337      75573
# 1      Monday  1114237052454  911938153513      76110
# 2    Saturday  1115661545514  909142081474      74725
# 3      Sunday  1192306179082  959223750461      75306
# 4    Thursday  1122723988662  920691927110      76607
# 5     Tuesday  1143313287046  942230721477      77303
# 6   Wednesday  1123655222441  920630864687      75713

# %%
days = days.reset_index()

# %%
days
# Out:
#   day_of_week        entries  \
# 0      Friday  1110224700078
# 1      Monday  1114237052454
# 2    Saturday  1115661545514
# 3      Sunday  1192306179082
# 4    Thursday  1122723988662
# 5     Tuesday  1143313287046
# 6   Wednesday  1123655222441
#
#    exits                                                                 \
# 0                                       906799065337
# 1                                       911938153513
# 2                                       909142081474
# 3                                       959223750461
# 4                                       920691927110
# 5                                       942230721477
# 6                                       920630864687
#
#    num_lines
# 0      75573
# 1      76110
# 2      74725
# 3      75306
# 4      76607
# 5      77303
# 6      75713

# %%
days['isweekend'] = days.day_of_week.map({'Monday':False,'Tuesday':False,'Wednesda':False,'Thursday':False,'Friday':False,'Saturday':True,'Sunday':True})

# %%
days.head()
# Out:
#   day_of_week        entries         exits  num_lines isweekend
# 0      Friday  1110224700078  906799065337      75573     False
# 1      Monday  1114237052454  911938153513      76110     False
# 2    Saturday  1115661545514  909142081474      74725      True
# 3      Sunday  1192306179082  959223750461      75306      True
# 4    Thursday  1122723988662  920691927110      76607     False

# %%
weekend = days.groupby('isweekend').mean()

# %%
weekend
# Out:
#                 entries         exits  num_lines
# isweekend
# False      1.122625e+12  9.204150e+11   76398.25
# True       1.153984e+12  9.341829e+11   75015.50

# %%
weekend[['entries','exits']].plot(kind='barh')

# %% [markdown]
# # Drop a couple of columns

# %%
df.drop(['c/a','scp'],axis=1)
# Out:
#         unit        station linename division       date      time     desc  \
# 0       R051          59 ST  NQR456W      BMT 2018-08-25  00:00:00  REGULAR
# 1       R051          59 ST  NQR456W      BMT 2018-08-25  04:00:00  REGULAR
# 2       R051          59 ST  NQR456W      BMT 2018-08-25  08:00:00  REGULAR
# 3       R051          59 ST  NQR456W      BMT 2018-08-25  12:00:00  REGULAR
# 4       R051          59 ST  NQR456W      BMT 2018-08-25  16:00:00  REGULAR
# 5       R051          59 ST  NQR456W      BMT 2018-08-25  20:00:00  REGULAR
# 6       R051          59 ST  NQR456W      BMT 2018-08-26  00:00:00  REGULAR
# 7       R051          59 ST  NQR456W      BMT 2018-08-26  04:00:00  REGULAR
# 8       R051          59 ST  NQR456W      BMT 2018-08-26  08:00:00  REGULAR
# 9       R051          59 ST  NQR456W      BMT 2018-08-26  12:00:00  REGULAR
# 10      R051          59 ST  NQR456W      BMT 2018-08-26  16:00:00  REGULAR
# ...
